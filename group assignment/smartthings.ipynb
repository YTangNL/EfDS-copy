# %%
import pandas as pd

# Read data from TSV file using pandas read_csv()
smartthings_df = pd.read_csv('data/smartthings/smartthings.202210.tsv.gz', sep='\t')
smartthings_df
# Out:
#             loc   level               name       epoch  \
# 0      bathroom     1st  Bathroom (flower)  1665346388
# 1      bathroom     1st  Bathroom (flower)  1665346402
# 2      bathroom     1st  Bathroom (flower)  1665347032
# 3      bathroom     1st  Bathroom (flower)  1665347091
# 4      bathroom     1st    Bathroom (sink)  1665347673
# ...         ...     ...                ...         ...
# 10552    ground  ground   Kitchen (stairs)  1667253741
# 10553    ground  ground   Kitchen (button)  1667256310
# 10554    ground  ground   Kitchen (button)  1667256612
# 10555   kitchen  ground        Door (main)  1667256875
# 10556   kitchen  ground        Door (main)  1667256875
#
#                         capability    attribute value unit
# 0                           switch       switch   off  NaN
# 1                           switch       switch    on  NaN
# 2                           switch       switch   off  NaN
# 3                           switch       switch    on  NaN
# 4                           switch       switch    on  NaN
# ...                            ...          ...   ...  ...
# 10552  relativeHumidityMeasurement     humidity    65    %
# 10553       temperatureMeasurement  temperature    19   °C
# 10554       temperatureMeasurement  temperature  19.1   °C
# 10555               signalStrength          lqi   202  NaN
# 10556               signalStrength         rssi   -67  dBm
#
# [10557 rows x 8 columns]

# %%
import glob
# Read the file paths from smartthings folder
folder_path = 'data/smartthings'
file_paths = glob.glob(os.path.join(folder_path, '*.tsv.gz'))

# %%
# Initialize an empty list to store dataframes
dfs = []
df=[]

# Read data from each file and append to the list
for i in range(0, len(file_paths)):
    df = pd.read_csv(file_paths[i], sep='\t')  # Replace with appropriate read function
    dfs.append(df)

# Concatenate dataframes vertically
combined_df = pd.concat(dfs, ignore_index=True)

# Now 'combined_df' contains data from all files
combined_df
# Out:
#               loc   level                   name       epoch  \
# 0        bathroom     1st  Bathroom (sensor eye)  1672527756
# 1        bathroom     1st  Bathroom (sensor eye)  1672527786
# 2        bathroom     1st  Bathroom (sensor eye)  1672527955
# 3        bathroom     1st  Bathroom (sensor eye)  1672528016
# 4        bathroom     1st  Bathroom (sensor eye)  1672528063
# ...           ...     ...                    ...         ...
# 1182205    garden  ground    Garden air (sensor)  1682891249
# 1182206  bathroom     1st  Bathroom (sensor eye)  1682891317
# 1182207     attic     2nd         Attic (sensor)  1682891786
# 1182208    garden  ground    Garden air (sensor)  1682891803
# 1182209    garden  ground    Garden air (sensor)  1682891803
#
#                           capability     attribute     value unit
# 0                 accelerationSensor  acceleration    active  NaN
# 1                 accelerationSensor  acceleration  inactive  NaN
# 2                 accelerationSensor  acceleration    active  NaN
# 3                 accelerationSensor  acceleration  inactive  NaN
# 4                 accelerationSensor  acceleration    active  NaN
# ...                              ...           ...       ...  ...
# 1182205       temperatureMeasurement   temperature      12.7   °C
# 1182206       temperatureMeasurement   temperature        21   °C
# 1182207       temperatureMeasurement   temperature      21.4   °C
# 1182208  relativeHumidityMeasurement      humidity        72    %
# 1182209       temperatureMeasurement   temperature      12.6   °C
#
# [1182210 rows x 8 columns]

# %%
# Check the duplicates
combined_df.duplicated().sum()
# Out:
# 0

# %%
# confirm the primary key
duplicates_exist = combined_df[['name','epoch','attribute','value']].duplicated().any()
duplicates_exist
# Out:
# False

# %%
# transform the epoch to time , i.e. unix timestamp to datetime
import datetime

current_timestamp = combined_df['epoch']

def timealign(x):
    dt_obj = datetime.datetime.utcfromtimestamp(x)
    return dt_obj.strftime("%Y-%m-%d %H:%M")

time_list = []
for i in current_timestamp:
    time_list.append(timealign(i))

combined_df['time']= time_list
combined_df
# Out:
# /var/folders/50/zp_xznfd1y91x5v78c8cn7g40000gn/T/ipykernel_88815/2678640790.py:8: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   dt_obj = datetime.datetime.utcfromtimestamp(x)
#               loc   level                   name       epoch  \
# 0        bathroom     1st  Bathroom (sensor eye)  1672527756
# 1        bathroom     1st  Bathroom (sensor eye)  1672527786
# 2        bathroom     1st  Bathroom (sensor eye)  1672527955
# 3        bathroom     1st  Bathroom (sensor eye)  1672528016
# 4        bathroom     1st  Bathroom (sensor eye)  1672528063
# ...           ...     ...                    ...         ...
# 1182205    garden  ground    Garden air (sensor)  1682891249
# 1182206  bathroom     1st  Bathroom (sensor eye)  1682891317
# 1182207     attic     2nd         Attic (sensor)  1682891786
# 1182208    garden  ground    Garden air (sensor)  1682891803
# 1182209    garden  ground    Garden air (sensor)  1682891803
#
#                           capability     attribute     value unit  \
# 0                 accelerationSensor  acceleration    active  NaN
# 1                 accelerationSensor  acceleration  inactive  NaN
# 2                 accelerationSensor  acceleration    active  NaN
# 3                 accelerationSensor  acceleration  inactive  NaN
# 4                 accelerationSensor  acceleration    active  NaN
# ...                              ...           ...       ...  ...
# 1182205       temperatureMeasurement   temperature      12.7   °C
# 1182206       temperatureMeasurement   temperature        21   °C
# 1182207       temperatureMeasurement   temperature      21.4   °C
# 1182208  relativeHumidityMeasurement      humidity        72    %
# 1182209       temperatureMeasurement   temperature      12.6   °C
#
#                      time
# 0        2022-12-31 23:02
# 1        2022-12-31 23:03
# 2        2022-12-31 23:05
# 3        2022-12-31 23:06
# 4        2022-12-31 23:07
# ...                   ...
# 1182205  2023-04-30 21:47
# 1182206  2023-04-30 21:48
# 1182207  2023-04-30 21:56
# 1182208  2023-04-30 21:56
# 1182209  2023-04-30 21:56
#
# [1182210 rows x 9 columns]

# %% [markdown]
# ### several related terms
# superkey: Any set of columns which has/will-have different values in each row.
#
# candidate key: A minimal superkey; such a set of columns that when a column is removed then there are/will-be duplicate rows. A table might have several candidate keys.
# - 'name','epoch','attribute','value'
#
# primary key: A chosen candidate key. The column names of a table primary key are often shown underlined.

# %%
# %pip install sqlalchemy_utils

# %%
import sqlalchemy as sa
import sqlalchemy.orm as orm
from sqlalchemy_utils import database_exists, create_database

# %%
engine = sa.create_engine("sqlite:///myhome.db",echo=False)

if not database_exists(engine.url):
    create_database(engine.url)

# %%
Base = orm.declarative_base()

class SmartThings(Base):
  __tablename__ = "smartthings"
  # these are notations
  name = sa.Column(sa.String(160),primary_key=True)
  time = sa.Column(sa.DateTime,primary_key=True)
  attribute= sa.Column(sa.String(160),primary_key=True)
  value = sa.Column(sa.String(160),primary_key=True)
  epoach = sa.Column(sa.Integer)
  loc = sa.Column(sa.String)
  level	= sa.Column(sa.String)
  capability = sa.Column(sa.String)
  unit = sa.Column(sa.String)

# %%
Base.metadata.create_all(engine)
